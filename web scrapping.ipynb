# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = "https://www.flipkart.com/search?q=kajal&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off"

# %%
allow = requests.get(url)

# %%
allow
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
kajal_name = soup.select(".s1Q9rs")

# %%
kajal_name
# Out:
# [<a class="s1Q9rs" href="/micio-grand-mystique-extra-black-kajal-water-proof/p/itmfajuuwhf2guzj?pid=KJLFAJUUT2ZZGGSS&amp;lid=LSTKJLFAJUUT2ZZGGSS5JKPDV&amp;marketplace=FLIPKART&amp;q=kajal&amp;store=g9b%2Fffi%2Fttr%2Fdbs&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_RzvZH73vd%2FJmIdM5Evxq3LoKG%2BhzJccziPGd4EY6a4FdJW8Mph9Q8MHpcSjgjcRv8nZQINP1P03wzEH964auKA%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=wqvajzt1e80000001653924568624&amp;qH=7faafcbcc6456af7" rel="noopener noreferrer" target="_blank" title="MICIO Grand Mystique Extra Black Kajal Water Proof">MICIO Grand Mystique Extra Black Kajal Water Proof</a>,
# ...

# %%
kajal = []
junk = []

# %%
for item in kajal_name:
    kajal.append(item.text)
    link = "https://www.flipkart.com"
    junk.append(link)

# %%
kajal
# Out:
# ['MICIO Grand Mystique Extra Black Kajal Water Proof',
#  'Mexmy Handmade Herbal Baby Kajal - 100% Natural & Ayurv...',
#  'Lakmé Eyeconic Kajal Pencil',
#  'Lakmé Eyeconic Kajal Twin Pack',
#  'MAYBELLINE NEW YORK Colossal Kajal Promo',
#  'Jaquline USA One Stroke Twin Pack',
#  'MAYBELLINE NEW YORK Colossal Kajal',
#  'Mexmy Herbal Baby Kajal - 100% Natural & Ayurvedic, Enr...',
#  'MAYBELLINE NEW YORK Call Me Colossal Kit - Colossal Wat...',
#  'FACES CANADA Magnet Eyes 24hrs Waterproof Kajal with Al...',
#  'Lakmé Eyeconic Insta Cool Kajal',
#  'Revlon Colorstay One-Stroke Defining Eyeliner Kajal',
#  'BLUE HEAVEN 2X Intense Kajal',
#  'Plum Eye-Swear-By Kohl Kajal - Deep Black | Creamy Smoo...',
#  'Organic Netra Baby Kajal-100% Chemical Free',
#  'Inatur Kajal| Long Lasting | Waterproof and Smudgeproof',
#  'MAYBELLINE NEW YORK Colossal Kajal, 0.35g',
#  'MamaEarth Charcoal Black Long Stay Kohl, Kajal Black Wa...',
#  'HIMALAYA Kajal',
# ...

# %%
rate_list = soup.select("._8VNy32 ._30jeq3")

# %%
rate_list
# Out:
# [<div class="_30jeq3">₹98</div>,
#  <div class="_30jeq3">₹236</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹195</div>,
#  <div class="_30jeq3">₹239</div>,
#  <div class="_30jeq3">₹84</div>,
#  <div class="_30jeq3">₹114</div>,
#  <div class="_30jeq3">₹238</div>,
#  <div class="_30jeq3">₹655</div>,
#  <div class="_30jeq3">₹77</div>,
#  <div class="_30jeq3">₹135</div>,
#  <div class="_30jeq3">₹612</div>,
#  <div class="_30jeq3">₹88</div>,
#  <div class="_30jeq3">₹187</div>,
#  <div class="_30jeq3">₹189</div>,
#  <div class="_30jeq3">₹133</div>,
#  <div class="_30jeq3">₹267</div>,
#  <div class="_30jeq3">₹363</div>,
#  <div class="_30jeq3">₹98</div>,
#  <div class="_30jeq3">₹650</div>,
#  <div class="_30jeq3">₹285</div>,
#  <div class="_30jeq3">₹317</div>,
#  <div class="_30jeq3">₹86</div>,
#  <div class="_30jeq3">₹389</div>,
#  <div class="_30jeq3">₹317</div>,
#  <div class="_30jeq3">₹382</div>,
#  <div class="_30jeq3">₹127</div>,
# ...

# %%
rate = []

# %%
for item in rate_list:
    rate.append(item.text)

# %%
rate
# Out:
# ['₹98',
#  '₹236',
#  '₹99',
#  '₹195',
#  '₹239',
#  '₹84',
#  '₹114',
#  '₹238',
#  '₹655',
#  '₹77',
#  '₹135',
#  '₹612',
#  '₹88',
#  '₹187',
#  '₹189',
#  '₹133',
#  '₹267',
#  '₹363',
#  '₹98',
#  '₹650',
#  '₹285',
#  '₹317',
#  '₹86',
#  '₹389',
#  '₹317',
#  '₹382',
#  '₹127',
#  '₹204',
#  '₹139',
#  '₹156',
#  '₹232',
#  '₹416',
#  '₹149',
#  '₹98',
#  '₹209',
#  '₹118',
#  '₹189',
#  '₹91',
#  '₹367',
#  '₹364']

# %%
import pandas as pd

# %%
kajal = pd.DataFrame(kajal,columns=["kajal_name"])

# %%
kajal["Rate"]=rate

# %%
kajal
# Out:
#                                            kajal_name  Rate
# 0   MICIO Grand Mystique Extra Black Kajal Water P...   ₹98
# 1   Mexmy Handmade Herbal Baby Kajal - 100% Natura...  ₹236
# 2                         Lakmé Eyeconic Kajal Pencil   ₹99
# 3                      Lakmé Eyeconic Kajal Twin Pack  ₹195
# 4            MAYBELLINE NEW YORK Colossal Kajal Promo  ₹239
# 5                   Jaquline USA One Stroke Twin Pack   ₹84
# 6                  MAYBELLINE NEW YORK Colossal Kajal  ₹114
# 7   Mexmy Herbal Baby Kajal - 100% Natural & Ayurv...  ₹238
# 8   MAYBELLINE NEW YORK Call Me Colossal Kit - Col...  ₹655
# 9   FACES CANADA Magnet Eyes 24hrs Waterproof Kaja...   ₹77
# 10                    Lakmé Eyeconic Insta Cool Kajal  ₹135
# 11  Revlon Colorstay One-Stroke Defining Eyeliner ...  ₹612
# 12                       BLUE HEAVEN 2X Intense Kajal   ₹88
# 13  Plum Eye-Swear-By Kohl Kajal - Deep Black | Cr...  ₹187
# 14        Organic Netra Baby Kajal-100% Chemical Free  ₹189
# ...

# %%
kajal.to_csv("vac assignment.csv")
